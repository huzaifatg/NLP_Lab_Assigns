# %%
import nltk
from nltk.corpus import wordnet as wn

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\huzai\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\huzai\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
word = "good"

# %%
synsets = wn.synsets(word)

# %% [markdown]
# **Synonyms (Synonymy)**

# %%
synonyms = set()

for syn in synsets:
    for lemma in syn.lemmas():
        synonyms.add(lemma.name())

print("Synonyms:", synonyms)
# Out:
# Synonyms: {'unspoilt', 'upright', 'right', 'practiced', 'near', 'undecomposed', 'commodity', 'full', 'honorable', 'estimable', 'serious', 'beneficial', 'good', 'just', 'secure', 'dear', 'effective', 'safe', 'salutary', 'goodness', 'sound', 'proficient', 'well', 'honest', 'thoroughly', 'unspoiled', 'skilful', 'adept', 'expert', 'ripe', 'trade_good', 'soundly', 'in_effect', 'dependable', 'in_force', 'respectable', 'skillful'}

# %% [markdown]
# **Antonyms (Antonymy)**

# %%
antonyms = set()

for syn in synsets:
    for lemma in syn.lemmas():
        if lemma.antonyms():
            antonyms.add(lemma.antonyms()[0].name())

print("Antonyms:", antonyms)
# Out:
# Antonyms: {'bad', 'evilness', 'ill', 'badness', 'evil'}

# %% [markdown]
# **Hypernyms (Hypernymy)**

# %%
hypernyms = set()

for syn in synsets:
    for hyper in syn.hypernyms():
        hypernyms.add(hyper.name())

print("Hypernyms:", hypernyms)
# Out:
# Hypernyms: {'artifact.n.01', 'quality.n.01', 'morality.n.01', 'advantage.n.01'}
